# %%
import pandas as pd

# %%
stats = pd.read_csv('Demographics.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#exploring the data
#1. getting data
print(stats)
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#2.Number of rows
len(stats)
# Out:
# 195

# %%
#3. Get Columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#4. length of columns
#5. get top 5 rows
print(len(stats.columns))
stats.head()#u can give number of rows u want in bracket eg. stats.head(9)
# Out:
# 5
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#6. bottom rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# 7. get info abt columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8.get description on columns
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# --------------------------

# %%
#Renaming columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns = ['a','b','c','d','e']

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns = ['Country Name', 'Country Code', 'Birth rate', 'Internet users',
       'Income Group']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# --------------

# %%
#slicing or subsetting
stats[10:1:-1]
# Out:
#             Country Name Country Code  Birth rate  Internet users  \
# 10            Azerbaijan          AZE      18.300         58.7000
# 9                Austria          AUT       9.400         80.6188
# 8              Australia          AUS      13.200         83.0000
# 7    Antigua and Barbuda          ATG      16.447         63.4000
# 6                Armenia          ARM      13.308         41.9000
# 5              Argentina          ARG      17.716         59.9000
# 4   United Arab Emirates          ARE      11.044         88.0000
# 3                Albania          ALB      12.877         57.2000
# 2                 Angola          AGO      45.985         19.1000
#
#            Income Group
# 10  Upper middle income
# 9           High income
# 8           High income
# 7           High income
# 6   Lower middle income
# 5           High income
# 4           High income
# 3   Upper middle income
# 2   Upper middle income

# %%
stats[1:20:5]
# Out:
#    Country Name Country Code  Birth rate  Internet users         Income Group
# 1   Afghanistan          AFG      35.253          5.9000           Low income
# 6       Armenia          ARM      13.308         41.9000  Lower middle income
# 11      Burundi          BDI      44.151          1.3000           Low income
# 16     Bulgaria          BGR       9.200         53.0615  Upper middle income

# %%
stats['Country Name']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: Country Name, Length: 195, dtype: object

# %%
stats[:5][['Country Name','Birth rate']]
# Out:
#            Country Name  Birth rate
# 0                 Aruba      10.244
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
['Country Name','Birth rate']
# Out:
# ['Country Name', 'Birth rate']

# %%
stats[['Country Name', 'Birth rate']]
# Out:
#              Country Name  Birth rate
# 0                   Aruba      10.244
# 1             Afghanistan      35.253
# 2                  Angola      45.985
# 3                 Albania      12.877
# 4    United Arab Emirates      11.044
# ..                    ...         ...
# 190           Yemen, Rep.      32.947
# 191          South Africa      20.850
# 192      Congo, Dem. Rep.      42.394
# 193                Zambia      40.471
# 194              Zimbabwe      35.715
#
# [195 rows x 2 columns]

# %%
stats.BirthRate * stats.InternetUsers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-3cff324b45a3> in <module>
# ----> 1 stats.BirthRate * stats.InternetUsers
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'BirthRate'

# %%
stats.columns = ['Country Name', 'Country Code', 'BirthRate', 'InternetUsers',
       'Income Group']

# %%
stats.BirthRate * stats.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
stats['myCalc'] = stats.BirthRate * stats.InternetUsers

# %%
stats.head()
# Out:
#            Country Name Country Code  BirthRate  InternetUsers  \
# 0                 Aruba          ABW     10.244           78.9
# 1           Afghanistan          AFG     35.253            5.9
# 2                Angola          AGO     45.985           19.1
# 3               Albania          ALB     12.877           57.2
# 4  United Arab Emirates          ARE     11.044           88.0
#
#           Income Group    myCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats.drop('myCalc',axis=1)
# Out:
#              Country Name Country Code  BirthRate  InternetUsers  \
# 0                   Aruba          ABW     10.244           78.9
# 1             Afghanistan          AFG     35.253            5.9
# 2                  Angola          AGO     45.985           19.1
# 3                 Albania          ALB     12.877           57.2
# 4    United Arab Emirates          ARE     11.044           88.0
# ..                    ...          ...        ...            ...
# 190           Yemen, Rep.          YEM     32.947           20.0
# 191          South Africa          ZAF     20.850           46.5
# 192      Congo, Dem. Rep.          COD     42.394            2.2
# 193                Zambia          ZMB     40.471           15.4
# 194              Zimbabwe          ZWE     35.715           18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
#to get individual cell value
print(stats.iat(0,3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b1a45e5fe01d> in <module>
#       1 #to get individual cell value
# ----> 2 print(stats.iat(0,3))
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given

# %%
stats.iat[0,3]
# Out:
# 78.9

# %%
stats.at[193,'Country Name']
# Out:
# 'Zambia'

# %% [markdown]
# ------------------------------

# %%
#filtering data frames
stats.BirthRate > 30
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191    False
# 192     True
# 193     True
# 194     True
# Name: BirthRate, Length: 195, dtype: bool

# %%
filter1 = stats.BirthRate > 30
filter2 = stats.InternetUsers < 10

# %%
stats[filter1 & filter2]
# Out:
#                  Country Name Country Code  BirthRate  InternetUsers  \
# 1                 Afghanistan          AFG     35.253           5.90
# 11                    Burundi          BDI     44.151           1.30
# 13                      Benin          BEN     36.440           4.90
# 14               Burkina Faso          BFA     40.551           9.10
# 29   Central African Republic          CAF     34.076           3.50
# 34              Cote d'Ivoire          CIV     37.320           8.40
# 35                   Cameroon          CMR     37.236           6.40
# 36                Congo, Rep.          COG     37.011           6.60
# 38                    Comoros          COM     34.326           6.50
# 52                    Eritrea          ERI     34.800           0.90
# 55                   Ethiopia          ETH     32.925           1.90
# 60                      Gabon          GAB     30.555           9.20
# 64                     Guinea          GIN     37.337           1.60
# ...

# %%
stats['Income Group'].unique
# Out:
# <bound method Series.unique of 0              High income
# 1               Low income
# 2      Upper middle income
# 3      Upper middle income
# 4              High income
#               ...
# 190    Lower middle income
# 191    Upper middle income
# 192             Low income
# 193    Lower middle income
# 194             Low income
# Name: Income Group, Length: 195, dtype: object>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
vis1 = sns.distplot(stats['InternetUsers'])

# %%
vis2 = sns.distplot(stats['BirthRate'], bins=20)

# %%
vis3 = sns.boxplot(data=stats, x="Income Group", y="BirthRate")
plt.rcParams['figure.figsize'] = 10,4

# %%
vis4 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", fit_reg=False, hue='Income Group',size=6, aspect=1.5,
                 scatter_kws = {'s':100})
